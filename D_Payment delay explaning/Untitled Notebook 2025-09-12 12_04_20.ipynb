# %% [markdown]
# ## Payment Delay Prediction Explanation
# This notebook prerequisites the exercise of the **payment delay** use case. We will learn how to integrate and utilize the SAP AI Core services, to interpret and explain the infered payment delay results. For that we will and show and cover the set up and cleaning of the data. We will prepare the data by handling missing values, removing duplicates and updating data types. Additionally, we will normalize the data, encode categorical variables and create new features. This is followed by a visualization of the distribution to identify any patterns or anomalies.
