# %% [markdown]
# ## Data Preparation Notebook
#
# This notebook will cover the set up and cleaning of the data. We will prepare the data by handling missing values, removing duplicates and updating data types. Additionally, we will normalize the data, encode categorical variables and create new features. This is followed by a visualization of the distribution to identify any patterns or anomalies.

# %% [markdown]
# ### Install necessary packages
#
# In the next few cells, we will install and import the required packages.

# %%
# %pip install databricks-feature-engineering
# %pip install ydata-profiling
# %restart_python
# Out:
# Requirement already satisfied: databricks-feature-engineering in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (0.12.1)
# Requirement already satisfied: mlflow-skinny<4,>=2.16.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.1.1)
# Requirement already satisfied: pyyaml<7,>=6 in /databricks/python3/lib/python3.11/site-packages (from databricks-feature-engineering) (6.0)
# Requirement already satisfied: boto3<2,>=1.16.7 in /databricks/python3/lib/python3.11/site-packages (from databricks-feature-engineering) (1.34.39)
# Requirement already satisfied: dbl-tempo<1,>=0.1.26 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from databricks-feature-engineering) (0.1.29)
# Requirement already satisfied: azure-cosmos==4.3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from databricks-feature-engineering) (4.3.1)
# Requirement already satisfied: numpy<3,>=1.19.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from databricks-feature-engineering) (1.26.4)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from databricks-feature-engineering) (4.25.8)
# Requirement already satisfied: flask<3,>=1.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from databricks-feature-engineering) (2.3.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /databricks/python3/lib/python3.11/site-packages (from databricks-feature-engineering) (0.5.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in /databricks/python3/lib/python3.11/site-packages (from azure-cosmos==4.3.1->databricks-feature-engineering) (1.32.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.39 in /databricks/python3/lib/python3.11/site-packages (from boto3<2,>=1.16.7->databricks-feature-engineering) (1.34.39)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /databricks/python3/lib/python3.11/site-packages (from boto3<2,>=1.16.7->databricks-feature-engineering) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /databricks/python3/lib/python3.11/site-packages (from boto3<2,>=1.16.7->databricks-feature-engineering) (0.10.3)
# Requirement already satisfied: Werkzeug>=2.3.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from flask<3,>=1.1.2->databricks-feature-engineering) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from flask<3,>=1.1.2->databricks-feature-engineering) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from flask<3,>=1.1.2->databricks-feature-engineering) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from flask<3,>=1.1.2->databricks-feature-engineering) (8.2.1)
# Requirement already satisfied: blinker>=1.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from flask<3,>=1.1.2->databricks-feature-engineering) (1.9.0)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (5.5.0)
# Requirement already satisfied: cloudpickle<4 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.55.0)
# Requirement already satisfied: fastapi<1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.115.14)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (6.0.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.34.1)
# Requirement already satisfied: packaging<26 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (23.2)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.11.7)
# Requirement already satisfied: requests<3,>=2.17.3 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.31.0)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.14.0)
# Requirement already satisfied: uvicorn<1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.34.3)
# Requirement already satisfied: azure-storage-file-datalake>12 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (12.14.0)
# Requirement already satisfied: google-cloud-storage>=1.30.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.18.2)
# Requirement already satisfied: databricks-agents<2.0,>=1.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.1.0)
# Requirement already satisfied: six>=1.11.0 in /usr/lib/python3/dist-packages (from azure-core<2.0.0,>=1.23.0->azure-cosmos==4.3.1->databricks-feature-engineering) (1.16.0)
# Requirement already satisfied: azure-storage-blob<13.0.0,>=12.19.0 in /databricks/python3/lib/python3.11/site-packages (from azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (12.19.1)
# Requirement already satisfied: isodate>=0.6.1 in /databricks/python3/lib/python3.11/site-packages (from azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /databricks/python3/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.39->boto3<2,>=1.16.7->databricks-feature-engineering) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.39->boto3<2,>=1.16.7->databricks-feature-engineering) (2.0.7)
# Requirement already satisfied: databricks-connect in /databricks/python3/lib/python3.11/site-packages (from databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (15.4.5)
# Requirement already satisfied: dataclasses-json in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.6.7)
# Requirement already satisfied: mlflow<4.0.0,>=3.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.1.1)
# Requirement already satisfied: tenacity>=8.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (9.1.2)
# Requirement already satisfied: tiktoken>=0.8.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.9.0)
# Requirement already satisfied: tqdm in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.67.1)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.35.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.46.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.0.11)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /databricks/python3/lib/python3.11/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.18.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /databricks/python3/lib/python3.11/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /databricks/python3/lib/python3.11/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /databricks/python3/lib/python3.11/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from Jinja2>=3.1.2->flask<3,>=1.1.2->databricks-feature-engineering) (3.0.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.55b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2023.7.22)
# Requirement already satisfied: h11>=0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from uvicorn<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.16.0)
# Requirement already satisfied: cryptography>=2.1.4 in /databricks/python3/lib/python3.11/site-packages (from azure-storage-blob<13.0.0,>=12.19.0->azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (41.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (5.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /databricks/python3/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.65.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /databricks/python3/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.25.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.9)
# Requirement already satisfied: alembic!=1.10.0,<2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.16.2)
# Requirement already satisfied: docker<8,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (7.1.0)
# Requirement already satisfied: graphene<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (23.0.0)
# Requirement already satisfied: matplotlib<4 in /databricks/python3/lib/python3.11/site-packages (from mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.7.2)
# Requirement already satisfied: pandas<3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.3.0)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (14.0.1)
# Requirement already satisfied: scikit-learn<2 in /databricks/python3/lib/python3.11/site-packages (from mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.3.0)
# Requirement already satisfied: scipy<2 in /databricks/python3/lib/python3.11/site-packages (from mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.11.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.0.41)
# Requirement already satisfied: anyio<5,>=3.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from tiktoken>=0.8.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2024.11.6)
# Requirement already satisfied: grpcio-status>=1.59.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from databricks-connect->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.62.3)
# Requirement already satisfied: grpcio>=1.59.3 in /databricks/python3/lib/python3.11/site-packages (from databricks-connect->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.69.0)
# Requirement already satisfied: py4j==0.10.9.7 in /databricks/python3/lib/python3.11/site-packages (from databricks-connect->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.10.9.7)
# Requirement already satisfied: setuptools>=68.0.0 in /databricks/python3/lib/python3.11/site-packages (from databricks-connect->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (75.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from dataclasses-json->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from dataclasses-json->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.9.0)
# Requirement already satisfied: Mako in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.3.10)
# Requirement already satisfied: sniffio>=1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.3.1)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.11/site-packages (from cryptography>=2.1.4->azure-storage-blob<13.0.0,>=12.19.0->azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.15.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from graphene<4->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from graphene<4->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (10.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.11/site-packages (from pandas<3->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from pandas<3->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2025.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.4.8)
# Requirement already satisfied: joblib>=1.1.1 in /databricks/python3/lib/python3.11/site-packages (from scikit-learn<2->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.11/site-packages (from scikit-learn<2->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.2.0)
# Requirement already satisfied: greenlet>=1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow<4.0.0,>=3.1.0->mlflow[databricks]<4.0.0,>=3.1.0->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->databricks-agents<2.0,>=1.0.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.4.3)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob<13.0.0,>=12.19.0->azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.21)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: ydata-profiling in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (4.16.1)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /databricks/python3/lib/python3.11/site-packages (from ydata-profiling) (1.11.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (2.3.0)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /databricks/python3/lib/python3.11/site-packages (from ydata-profiling) (3.7.2)
# Requirement already satisfied: pydantic>=2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (2.11.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /databricks/python3/lib/python3.11/site-packages (from ydata-profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /databricks/python3/lib/python3.11/site-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /databricks/python3/lib/python3.11/site-packages (from ydata-profiling) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /databricks/python3/lib/python3.11/site-packages (from ydata-profiling) (0.14.0)
# Requirement already satisfied: typeguard<5,>=3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in /databricks/python3/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (23.2)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /databricks/python3/lib/python3.11/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.2 in /databricks/python3/lib/python3.11/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.3)
# Requirement already satisfied: attrs>=19.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in /local_disk0/.ephemeral_nfs/envs/pythonEnv-5cc5acc4-6a79-443a-a203-ee196e32e29a/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.29)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ### Import packages

# %%
from databricks.feature_engineering import FeatureEngineeringClient
from pyspark.sql import SparkSession
from pyspark.sql.functions import to_date, col, date_trunc, sum, explode, sequence, min, max, lit, expr, datediff, row_number, when
from pyspark.sql.window import Window
from ydata_profiling import ProfileReport
import pandas as pd
import mlflow
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# ### Set necessary parameters
#
# Please replace the values `<CATALOG_NAME>` and `<SCHEMA_NAME>` with the specific values that match our use case and group. You can find the correct names by checking the **Unity Catalog** and look for the specific catalog and schema names:`uc_XXX`, `grpX`. Additionally, please replace the value `<TIME_SERIES_TABLE_NAME>` with the according name.
#
# Please note:
# We adapted the code here to match our use case. Therefore, some of the lines are commented out and not needed. However, they can be useful for future applications.

# %%
# %sql
-- CREATE CATALOG IF NOT EXISTS <CATALOG_NAME>;
SET CATALOG uc_delayed_payment;
-- CREATE SCHEMA IF NOT EXISTS <SCHEMA_NAME>;
USE SCHEMA grp1;

# %% [markdown]
# Replace the values `<DELTA_SHARE>` with the according `cashflow` delta share name. You'll find the correct name by checking the **Unity Catalog**.
#
# Hint: You'll need to refer to the correct table within the schema.

# %%
data = spark.read.table("bdc_entryviewjournal.entryviewjournalentry.operationalacctgdocitem")

# %% [markdown]
# ## Data Preparation
# Use the following code to drop unneccessary columns. Add the following columns to the list of columns that need to be dropped (`<COLUMNS_TO_DROP>`):
# - CashDiscount2DueDate
# - CashDiscount1DueDate
# - DocumentDate
# - PostingDate
# - TaxDeterminationDate
# - AcctgDocItmCstmsClearanceDate
# - DueCalculationBaseDate
# - AssetValueDate
# - ValueDate
# - ClearingCreationDate

# %%
selected_data = data.drop("CashDiscount2DueDate", "CashDiscount1DueDate", "DocumentDate", "PostingDate", "TaxDeterminationDate", "AcctgDocItmCstmsClearanceDate", "DueCalculationBaseDate", "AssetValueDate", "ValueDate", "ClearingCreationDate")

# %% [markdown]
# Now adjust the following code to replace empty strings with `None`.

# %%
transactional_data = selected_data.replace('', None)

# %%
from pyspark.sql.functions import max, col

# %% [markdown]
# In the following cell, we will drop unnecessary columns from our dataset.

# %%
def drop_fully_null_columns(df, but_keep_these=[]):
    """Drops DataFrame columns that are fully null
    (i.e. the maximum value is null)

    Arguments:
        df {spark DataFrame} -- spark dataframe
        but_keep_these {list} -- list of columns to keep without checking for nulls

    Returns:
        spark DataFrame -- dataframe with fully null columns removed
    """

    # skip checking some columns
    cols_to_check = [col for col in df.columns if col not in but_keep_these]
    if len(cols_to_check) > 0:
        # drop columns for which the max is None
        rows_with_data = df.select(*cols_to_check).groupby().agg(*[max(c).alias(c) for c in cols_to_check]).take(1)[0]
        cols_to_drop = [c for c, const in rows_with_data.asDict().items() if const == None]
        cleaned_df = df.drop(*cols_to_drop)

        return cleaned_df
    else:
        return df

# %% [markdown]
# Set the primary keys by adding the following columns to the list of primary keys `<PRIMARY_KEYS>`. The following columns should be set as primary keys:
# - CompanyCode
# - AccountingDocument
# - FiscalYear
# - AccountingDocumentItem

# %%
primary_key = ["CompanyCode", "AccountingDocument", "FiscalYear", "AccountingDocumentItem"]

# %%
transactional_data = transactional_data.where(col("Customer").isNotNull())

# %%
transactional_data = drop_fully_null_columns(transactional_data)
converted_data_types = {column: col(column).cast('integer').alias(column) for column, column_dtype in transactional_data.dtypes if column_dtype == 'boolean'}
if converted_data_types:
    transactional_data = transactional_data.withColumns(converted_data_types)
replace_string_values = {column: f"No{column}" for column, col_dtypes in transactional_data.dtypes if col_dtypes == "string" and column not in primary_key}
prepared_transactional_data = transactional_data.fillna(replace_string_values)

# %% [markdown]
# ## Filter Data
# We only need the data where we have a value for the column `Customer`. Please adjust the following code to make sure data with the value `NoCustomer`is filtered out by replacing the value `<SET_FILTER>`.

# %%
prepared_transactional_data = prepared_transactional_data.where(col("Customer") != "NoCustomer")

# %% [markdown]
# ## Delay Prediction
# To create a delay prediction data set we need to select the columns that have an actual delay.

# %%
# Calculate the delay in days between ClearingDate and NetDueDate
delay_prediction_dataset = prepared_transactional_data.\
    withColumn("delay", datediff("ClearingDate", "NetDueDate")).\
    withColumn("delay", when(col("delay") < 0, 0).otherwise(col("delay")))

# %% [markdown]
# For the column `delay` we need the values to be bigger or equal to `0`. Adjust the following code to match these requirements by changing the value of `<SET_FILTER>`.

# %%
delay_prediction_dataset = delay_prediction_dataset.where(col("delay") >= 0)

# %% [markdown]
# ## Create and Save Table

# %%
mlflow.set_registry_uri("databricks-uc")
fe_client = FeatureEngineeringClient()

# %%
fe_client.create_table(
    name="prepared_accounting_document",
    primary_keys=primary_key,
    schema=delay_prediction_dataset.schema,
    description="Prepared Accounting document item data product for payment delay forecasting"
)
# Out:
# 2025/07/07 16:15:32 INFO databricks.ml_features._compute_client._compute_client: Setting columns ['CompanyCode', 'AccountingDocument', 'FiscalYear', 'AccountingDocumentItem'] of table 'playground_emea.default.prepared_accounting_document' to NOT NULL.
# 2025/07/07 16:15:36 INFO databricks.ml_features._compute_client._compute_client: Setting Primary Keys constraint ['CompanyCode', 'AccountingDocument', 'FiscalYear', 'AccountingDocumentItem'] on table 'playground_emea.default.prepared_accounting_document'.
# 2025/07/07 16:15:37 INFO databricks.ml_features._compute_client._compute_client: Created feature table 'playground_emea.default.prepared_accounting_document'.
# <FeatureTable: name='playground_emea.default.prepared_accounting_document', table_id='40e1a1e0-3027-45eb-a5f2-838096eec2eb', description='Prepared Accounting document item data product for payment delay forecasting', primary_keys=['CompanyCode', 'AccountingDocument', 'FiscalYear', 'AccountingDocumentItem'], partition_columns=[], features=['CompanyCode',
#  'AccountingDocument',
#  'FiscalYear',
#  'AccountingDocumentItem',
#  'ChartOfAccounts',
#  'AccountingDocumentItemType',
#  'ClearingDate',
#  'ClearingJournalEntryFiscalYear',
#  'ClearingDocFiscalYear',
#  'ClearingJournalEntry',
#  'ClearingAccountingDocument',
#  'PostingKey',
#  'FinancialAccountType',
#  'SpecialGLCode',
#  'SpecialGLTransactionType',
#  'DebitCreditCode',
#  'BusinessArea',
#  'TaxCode',
#  'WithholdingTaxCode',
#  'TaxItemGroup',
#  'TransactionTypeDetermination',
#  'AssignmentReference',
#  'DocumentItemText',
#  'PartnerCompany',
#  'CorporateGroupAccount',
#  'PlanningLevel',
#  'ControllingArea',
#  'CostCenter',
#  'OrderID',
#  'BillingDocument',
#  'SalesDocument',
#  'SalesDocumentItem',
#  'ScheduleLine',
#  'ServiceDocumentItem',
#  'PersonnelNumber',
#  'IsSalesRelated',
#  'LineItemDisplayIsEnabled',
#  'IsOpenItemManaged',
#  'AddressAndBankIsSetManually',
#  'DownPaymentIsNetProcedure',
#  'IsNotCashDiscountLiable',
#  'IsAutomaticallyCreated',
#  'IsUsedInPaymentTransaction',
#  'OperationalGLAccount',
#  'GLAccount',
#  'Customer',
#  'Supplier',
#  'IsBalanceSheetAccount',
#  'ProfitLossAccountType',
#  'SpecialGLAccountAssignment',
#  'PaymentTerms',
#  'CashDiscount1Days',
#  'CashDiscount2Days',
#  'NetPaymentDays',
#  'CashDiscount1Percent',
#  'CashDiscount2Percent',
#  'PaymentMethod',
#  'PaymentBlockingReason',
#  'HouseBank',
#  'BPBankAccountInternalID',
#  'TaxDistributionCode1',
#  'TaxDistributionCode2',
#  'InvoiceReference',
#  'InvoiceReferenceFiscalYear',
#  'InvoiceItemReference',
#  'FollowOnDocumentType',
#  'SupplyingCountry',
#  'InvoiceList',
#  'DunningBlockingReason',
#  'DunningLevel',
#  'WithholdingTaxCertificate',
#  'Material',
#  'Product',
#  'Plant',
#  'PurchasingDocument',
#  'PurchasingDocumentItem',
#  'AccountAssignmentNumber',
#  'IsCompletelyDelivered',
#  'MaterialPriceControl',
#  'ValuationArea',
#  'InventoryValuationType',
#  'VATRegistration',
#  'DelivOfGoodsDestCountry',
#  'DelivOfGoodsOriginCountry',
#  'ProfitCenter',
#  'TreasuryContractType',
#  'AssetContract',
#  'CashFlowType',
#  'TaxJurisdiction',
#  'OrderInternalBillOfOperations',
#  'OrderIntBillOfOperationsItem',
#  'WBSElementInternalID',
#  'ProfitabilitySegment',
#  'ProfitabilitySegment_2',
#  'IsEUTriangularDeal',
#  'CompanyCodeCurrencyDetnMethod',
#  'ClearingIsReversed',
#  'AlternativeGLAccount',
#  'PartnerProfitCenter',
#  'Reference1IDByBusinessPartner',
#  'Reference2IDByBusinessPartner',
#  'EarmarkedFundsDocumentItem',
#  'IsNegativePosting',
#  'PaymentCardItem',
#  'CreditControlArea',
#  'Reference3IDByBusinessPartner',
#  'DataExchangeInstruction1',
#  'DataExchangeInstruction2',
#  'DataExchangeInstruction3',
#  'DataExchangeInstruction4',
#  'HasPaymentOrder',
#  'PaymentReference',
#  'ClearingItem',
#  'BusinessPlace',
#  'FunctionalArea',
#  'CustomerIsInExecution',
#  'Segment',
#  'PartnerSegment',
#  'HouseBankAccount',
#  'CostElement',
#  'TaxItemAcctgDocItemRef',
#  'ReferenceDocumentType',
#  'OriginalReferenceDocument',
#  'ReferenceDocumentLogicalSystem',
#  'AccountingDocumentItemRef',
#  'FiscalPeriod',
#  'AccountingDocumentCategory',
#  'AccountingDocumentType',
#  'NetDueDate',
#  'OffsettingAccount',
#  'OffsettingAccountType',
#  'OffsettingChartOfAccounts',
#  'CustomerGroup',
#  'CustomerSupplierCountry',
#  'CompanyCodeCurrency',
#  'AmountInCompanyCodeCurrency',
#  'FunctionalCurrency',
#  'AmountInFunctionalCurrency',
#  'TaxAmountInCoCodeCrcy',
#  'TaxBaseAmountInCoCodeCrcy',
#  'ValuationDiffAmtInCoCodeCrcy',
#  'CashDiscountAmtInCoCodeCrcy',
#  'TaxBrkdwnAmount1InCoCodeCrcy',
#  'TaxBrkdwnAmount2InCoCodeCrcy',
#  'TaxBrkdwnAmount3InCoCodeCrcy',
#  'NonDcblTaxAmountInCoCodeCrcy',
#  'InvoiceAmtInCoCodeCrcy',
#  'TransactionCurrency',
#  'AmountInTransactionCurrency',
#  'OriginalTaxBaseAmount',
#  'TaxAmount',
#  'TaxBaseAmountInTransCrcy',
#  'WithholdingTaxBaseAmount',
#  'PlannedAmtInTransactionCrcy',
#  'CashDiscountBaseAmount',
#  'CashDiscountAmount',
#  'NetPaymentAmount',
#  'TaxBrkdwnAmount1InTransCrcy',
#  'TaxBrkdwnAmount2InTransCrcy',
#  'TaxBrkdwnAmount3InTransCrcy',
#  'WithholdingTaxAmount',
#  'WithholdingTaxExemptionAmt',
#  'NonDcblTaxAmountInTransCrcy',
#  'InvoiceAmountInFrgnCurrency',
#  'BalanceTransactionCurrency',
#  'AmountInBalanceTransacCrcy',
#  'AdditionalCurrency1',
#  'ValuationDiffAmtInAddlCrcy1',
#  'AmountInAdditionalCurrency1',
#  'TaxAmountInAdditionalCurrency1',
#  'AdditionalCurrency2',
#  'AmountInAdditionalCurrency2',
#  'TaxAmountInAdditionalCurrency2',
#  'ValuationDiffAmtInAddlCrcy2',
#  'AmountInPaymentCurrency',
#  'CreditControlAreaCurrency',
#  'HedgedAmount',
#  'BaseUnit',
#  'Quantity',
#  'GoodsMovementEntryUnit',
#  'QuantityInEntryUnit',
#  'PurchasingDocumentPriceUnit',
#  'PurchaseOrderQty',
#  'MaterialPriceUnitQty',
#  'AbsoluteAmountInCoCodeCrcy',
#  'AbsoluteAmountInTransacCrcy',
#  'AbsltAmtInAdditionalCurrency1',
#  'AbsltAmtInAdditionalCurrency2',
#  'AbsltAmtInBalanceTransacCrcy',
#  'AbsltAmtInFunctionalCurrency',
#  'AbsltAmountInPaymentCurrency',
#  'HedgedAbsoluteAmount',
#  'PlannedAbsltAmtInTransCrcy',
#  'CashDiscAbsltAmtInCoCodeCrcy',
#  'CashDiscountAbsoluteAmount',
#  'CashDiscountAbsoluteBaseAmount',
#  'InvoiceAbsltAmtInCoCodeCrcy',
#  'InvoiceAbsltAmtInFrgnCurrency',
#  'NetPaymentAbsoluteAmount',
#  'NonDcblTaxAbsltAmtInCoCodeCrcy',
#  'NonDcblTaxAbsltAmtInTransCrcy',
#  'TaxAbsltAmountInCoCodeCrcy',
#  'TaxAbsoluteAmount',
#  'TaxAbsltAmtInAddlCurrency1',
#  'TaxAbsltAmtInAddlCurrency2',
#  'TaxAbsltBaseAmountInCoCodeCrcy',
#  'TaxAbsltBaseAmountInTransCrcy',
#  'OriglTxAbsltBaseAmountInCCCrcy',
#  'OriginalTaxAbsoluteBaseAmount',
#  'OriglTxAbsltBaseAmtInAddlCrcy1',
#  'OriglTxAbsltBaseAmtInAddlCrcy2',
#  'TaxBrkdwnAbsltAmt1InCoCodeCrcy',
#  'TaxBrkdwnAbsltAmt2InCoCodeCrcy',
#  'TaxBrkdwnAbsltAmt3InCoCodeCrcy',
#  'TaxBrkdwnAbsltAmt1InTransCrcy',
#  'TaxBrkdwnAbsltAmt2InTransCrcy',
#  'TaxBrkdwnAbsltAmt3InTransCrcy',
#  'WithholdingTaxAbsoluteAmount',
#  'WithholdingTaxAbsoluteBaseAmt',
#  'WhldgTaxExemptionAbsltAmount',
#  'ValnDiffAbsltAmtInCoCodeCrcy',
#  'ValnDiffAbsltAmtInAddlCrcy1',
#  'ValnDiffAbsltAmtInAddlCrcy2',
#  'UnadjustedDebitCreditCode',
#  'NumberOfItems',
#  'EarmarkedFundsItem',
#  'OriglTaxBaseAmountInCoCodeCrcy',
#  'OriginalTaxBaseAmtInAddlCrcy1',
#  'OriginalTaxBaseAmtInAddlCrcy2',
#  'OperationalAcctgDocItemOID',
#  '__OPERATION_TYPE',
#  '__TIMESTAMP',
#  'load_type_8995a2862a8343bd8390aaa82c46e881',
#  'run_id_8995a2862a8343bd8390aaa82c46e881',
#  'delay'], creation_timestamp=1751904932148, online_stores=[], notebook_producers=[], job_producers=[], table_data_sources=[], path_data_sources=[], custom_data_sources=[], timestamp_keys=[], tags={}>

# %% [markdown]
# Next, replace `<TABLE_NAME>` by the name of the table that we created for the delay prediction.

# %%
fe_client.write_table(
    name="prepared_accounting_document",
    df=delay_prediction_dataset,
    mode="merge"
)
